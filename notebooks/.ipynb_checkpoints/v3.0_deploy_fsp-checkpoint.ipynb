# %% [markdown]
# # PA004: Health Insurance cross sell

# %% [markdown]
# ##  Planejamento da solução (IOT)

# %% [markdown]
# ### Database

# %% [markdown]
# Information about customers who participate in a survey by answering whether they would be interested in car insurance.

# %% [markdown]
# ### Input

# %% [markdown]
# 1. Build a model to order customers most likely to buy vehicle insurance.

# %% [markdown]
# ### Business Questions

# %% [markdown]
# 1. Main Insights on the most relevant attributes of customers interested in purchasing auto insurance.
#
#
#
#
# 2. What percentage of customers interested in purchasing auto insurance will the sales team be able to contact by making 20,000 calls?
#
#
#
#
#
# 3. If the sales team capacity increases to 40,000 calls, what percentage of customers interested in purchasing auto insurance will the sales team be able to contact?
#
#
#
#
#
#
# 4. How many calls does the sales team need to make to contact 80% of customers interested in purchasing auto insurance?

# %% [markdown]
# ### Output

# %% [markdown]
# 1. Customers interested in car insurance for the sales team to call.
#
#        Customer Id |   interest %
#            01      |     0.99
#            02      |     0.97
#            03      |     0.90
#
# 2. Report with business Questions

# %% [markdown]
# ### Tasks

# %% [markdown]
#   1. Model to rank customers by higher interest in car insurance
#
#
#
#
#
#   2. Exploratory Data Analysis Report about the top feature importance
#
#
#
#
#
#   3. The number of customers interested in car insurance

# %% [markdown]
# # 0.0. IMPORTS

# %%
import pickle 
import requests
import os


import seaborn                                                     as sns
import pandas                                                      as pd
import psycopg2                                                    as pg
import numpy                                                       as np
import scikitplot                                                  as skplt
import matplotlib
from matplotlib                    import pyplot                   as plt
from tabulate                      import tabulate
import sweetviz                                                    as sv


from IPython.core.display          import HTML

# machine learning
from sklearn                       import neighbors                as nh
from sklearn                       import preprocessing            as pp
from sklearn                       import model_selection          as ms
from sklearn                       import ensemble                 as en
from catboost                      import CatBoostClassifier       as cb
from xgboost                       import XGBClassifier 

import cross_validation                                            as cv
from cross_validation              import runCrossValidation

# metrics
from scikitplot.metrics            import plot_lift_curve, plot_cumulative_gain
from sklearn.metrics               import roc_auc_score


from flask                        import Flask, request, Response
from dotenv                       import load_dotenv, find_dotenv
from tabulate                     import tabulate
import random

import warnings

warnings.filterwarnings("ignore")
# Out:
# /home/felipepedrosa/anaconda3/envs/health_insurance/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ## 0.1 Loading Data - Postgres

# %%
path = '/home/felipepedrosa/projetos/health_insurance'

# %%
datapath = '../data/'

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
# credentials
HOST     = os.environ.get( 'DB_HOST' )
PORT     = os.environ.get( 'DB_PORT' ) 
DATABASE = os.environ.get( 'DB_DATABASE' )
USERNAME = os.environ.get( 'DB_USERNAME' ) 
PASSWORD = os.environ.get( 'DB_PASSWORD' )

# %%
# conn = pg.connect(user = USERNAME, password = PASSWORD, host = HOST, port = PORT, database = DATABASE)

# query_schema = '''
#     SELECT *
#     FROM pa004.users u  INNER JOIN pa004.vehicle v on (u.id = v.id)
#                         INNER JOIN pa004.insurance i on (u.id = i.id)
# '''

# df_raw = pd.read_sql(query_schema, conn)

# conn.close()

# df_raw.to_pickle(path + '/data/raw/df_raw.pkl')

# %%
df0 = pd.read_pickle(path + '/data/raw/df_raw.pkl')

# %% [markdown]
# ## 0.2 Helper Functions

# %%
def my_settings():
    # %matplotlib inline
    
    # plotly settings
    plt.style.use( 'ggplot' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 8
 
    # notebook settings
    display(HTML('<style>.container{width:100% !important;}</style>'))
    np.set_printoptions(suppress=True)
    pd.set_option('display.float_format', '{:.8f}'.format)
    
    # seaborn settings
    sns.set(rc={'figure.figsize':(25,12)})
    sns.set_theme(style = 'darkgrid', font_scale = 1)
my_settings()
# Out:
# <style>.container{width:100% !important;}</style>

# %%
def descriptive_stats(df): 
    # Central Tendency - Mean, Median
    ct1 = pd.DataFrame( num_attributes.apply( np.mean ) ).T
    ct2 = pd.DataFrame( num_attributes.apply( np.median ) ).T

    # dispersion - std, min, max, range, skew, kurtosis
    d1 = pd.DataFrame( num_attributes.apply( np.std ) ).T 
    d2 = pd.DataFrame( num_attributes.apply( min ) ).T 
    d3 = pd.DataFrame( num_attributes.apply( max ) ).T 
    d4 = pd.DataFrame( num_attributes.apply( lambda x: x.max() - x.min() ) ).T 
    d5 = pd.DataFrame( num_attributes.apply( lambda x: x.skew() ) ).T 
    d6 = pd.DataFrame( num_attributes.apply( lambda x: x.kurtosis() ) ).T 

    # concatenar
    m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
    m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
    
    return m

# %%
def gain_lift_curve(yhat, yval, plot = True, size = (6,8), axvline="None"):
    '''
    plots gain and lift curve, respectively
    returns the curves and a table used to plot the curves
    '''

    # create table proba with the propensity score for each class (0 and 1)
    table_proba = pd.DataFrame(yhat)

    # add the 'response' column
    table_proba['target'] = yval.values

    # add the 'correct' column to evaluate wheter the prediction was right or not
    x = lambda x: "yes" if x[0] > x[1] and x['target'] == 0 else "yes" if x[1] > x[0] and x['target'] == 1 else "yes" if x[0] == x[1] else "no" 
    table_proba['correct'] = table_proba.apply(x, axis = 1)

    # order by propensity score for the class 1
    table_proba.sort_values(1, ascending = False, inplace = True)

    # create cumulative propensity score
    ## calculate the quantity of class 1 rows
    qty_class_1 = table_proba.groupby('target').count().loc[1,1]

    ## apply a score for every row which target is 1
    x = lambda x: 1/qty_class_1 if x['target'] == 1 else 0
    table_proba['propensity_score'] = table_proba.apply(x, axis = 1)
    table_proba['cumulative_propensity_score'] = np.cumsum(table_proba['propensity_score'])

    # create % cumulative of the base
    x = lambda x: 1/len(table_proba)
    table_proba['porc_base'] = table_proba.apply(x, axis = 1)
    table_proba['cumulative_porc_base'] = np.cumsum(table_proba['porc_base'])
    table_proba.drop('porc_base', axis = 1, inplace = True)

    # create the lift column
    table_proba['lift'] = table_proba['cumulative_propensity_score'] / table_proba['cumulative_porc_base']

    if plot:
        fig, axes = plt.subplots(2, 1, figsize=size)

        # gap between graphics
        fig.tight_layout(pad =5)

        # gain curve
        sns.lineplot(ax = axes[0], x = table_proba['cumulative_porc_base'], y = table_proba['cumulative_propensity_score'], label="cumulative (model)", linewidth = 2.5);
        sns.lineplot(ax = axes[0], x = table_proba['cumulative_porc_base'], y = table_proba['cumulative_porc_base'], label="baseline", linewidth = 2.5, color = 'black' )
        axes[0].lines[1].set_linestyle("--")
        axes[0].legend()
        axes[0].set_title("cumulative gains curve")
        axes[0].set_xlabel("percentage of sample")
        axes[0].set_ylabel("gain")
        
        if axvline != "None":
            axes[0].axvline(axvline, 0, 1, color='green', ls='--', lw=2)
        
        # lift curve
        ## do not consider the beginning of the series, as it varies a lot (the sample is still small)
        table_proba_filtered = table_proba.query('cumulative_porc_base >= 0.1')

        sns.lineplot(ax = axes[1], x = table_proba_filtered['cumulative_porc_base'], y = table_proba_filtered['lift'], label="model", linewidth = 2.5 );
        sns.lineplot(ax = axes[1], x = table_proba_filtered['cumulative_porc_base'], y = np.ones(len(table_proba_filtered)), label="baseline", linewidth = 2.5, color = 'black' )
        axes[1].lines[1].set_linestyle("--")
        axes[1].legend()
        axes[1].set_title("lift curve")
        axes[1].set_xlabel("percentage of sample")

        if axvline != "None":
            axes[1].axvline(axvline, 0, 1, color='green', ls='--', lw=2)
        
        plt.show();
        
    return (table_proba)


def precision_recall_at_k(table, k=2000):
    ''' receives the dataset and returns: 
    - a tuple containg the precision at k and recall at k, respectively
    - a new table with precision_at_k and recall_at_k metrics '''
    # reset index
    table = table.reset_index (drop=True)
    # create ranking order
    table['ranking'] = table.index + 1 # as the index starts in 0 it is necessary to +1
    # calculate precision and recall
    table['precision_at_k'] = table['target'].cumsum() / table['ranking']
    table['recall_at_k'] = table['target'].cumsum() / table['target'].sum()

    return ((table.loc[k-1, 'precision_at_k'], table.loc[k-1, 'recall_at_k']),table)# as the loc uses index, it is necessAry to -1 to return the desired k


def compiled_precision_recall(list_of_dfs):
    dict_precision = {'Precision@': ['10% (3049)', '20% (6098)', '30% (9147)', '40% (12196)']}
    dict_recall = {'Recall@': ['10% (3049)', '20% (6098)', '30% (9147)', '40% (12196)']}
    
    for model in list_of_dfs:
        
        metrics10, _ = precision_recall_at_k(eval(model),3049)
        metrics20, _ = precision_recall_at_k(eval(model),6098)
        metrics30, _ = precision_recall_at_k(eval(model),9147)
        metrics40, _ = precision_recall_at_k(eval(model),12196)
        
        dict_precision[model] = [round(metrics10[0], 2),
                                 round(metrics20[0], 2),
                                 round(metrics30[0], 2), 
                                 round(metrics40[0], 2)]

        dict_recall[model] = [round(metrics10[1], 2), 
                              round(metrics20[1], 2),
                              round(metrics30[1], 2), 
                              round(metrics40[1], 2)]
        
    df_precision = pd.DataFrame(dict_precision).set_index('Precision@')
    df_recall = pd.DataFrame(dict_recall).set_index('Recall@')
    
    df_precision.columns = ['k-nearest neighbors',
                            'logistic regression',
                            'extra trees classifier',
                            'xgboost classifier',
                            'perfect model']
     
    df_recall.columns = ['k-nearest neighbors',
                            'logistic regression',
                            'extra trees classifier',
                            'xgboost classifier',
                            'perfect model' ]
    
    return (df_precision, df_recall)

# %% [markdown]
# # 1.0. Data Description

# %% [markdown]
# ### RENAME COLUMNS

# %%
df1 = df0.copy()

# %%
 df1 = df1.rename(columns={'previously_insured': 'vehicle_prev_insured',
                        'annual_premium': 'health_annual_paid',
                        'vintage': 'days_associated'})
df1
# Out:
#             id  gender  age  region_code  policy_sales_channel      id  \
# 0            7    Male   23  11.00000000          152.00000000       7
# 1           13  Female   41  15.00000000           14.00000000      13
# 2           18  Female   25  35.00000000          152.00000000      18
# 3           31  Female   26   8.00000000          160.00000000      31
# 4           39    Male   45   8.00000000          124.00000000      39
# ...        ...     ...  ...          ...                   ...     ...
# 381104  381070    Male   24   8.00000000          152.00000000  381070
# 381105  381079  Female   58  28.00000000           26.00000000  381079
# 381106  381082  Female   75  28.00000000           26.00000000  381082
# 381107  381097  Female   49  10.00000000           26.00000000  381097
# 381108  381100  Female   51  28.00000000           26.00000000  381100
#
#         driving_license vehicle_age vehicle_damage      id  \
# 0                     1    < 1 Year            Yes       7
# 1                     1    1-2 Year             No      13
# 2                     1    < 1 Year             No      18
# 3                     1    < 1 Year             No      31
# 4                     1    1-2 Year            Yes      39
# ...                 ...         ...            ...     ...
# 381104                1    < 1 Year             No  381070
# 381105                1    1-2 Year            Yes  381079
# 381106                1    1-2 Year             No  381082
# 381107                1    1-2 Year            Yes  381097
# 381108                1    1-2 Year            Yes  381100
#
#         vehicle_prev_insured  health_annual_paid  days_associated  response
# 0                          0      23367.00000000              249         0
# 1                          1      31409.00000000              221         0
# 2                          1      46622.00000000              299         0
# 3                          0       2630.00000000              136         0
# 4                          0      42297.00000000              264         0
# ...                      ...                 ...              ...       ...
# 381104                     1      38254.00000000              127         0
# 381105                     0      39740.00000000              170         0
# 381106                     1      51619.00000000               80         0
# 381107                     0      34541.00000000               44         0
# 381108                     0      44504.00000000               71         0
#
# [381109 rows x 14 columns]

# %%
tab_meanings = [['Column', 'Meaning'],
    #####################################################  
        ['id', 'unique customer identifier.'],
        ['gender', 'client gender: Male / Female.'],
        ['age', 'customer age.'],
        ['region_code', 'customer region code.'],
        ['policy_sales_channel', 'Anonymized Code for the channel of outreaching to the customer. Ie: Over Mail, Over Phone, In Person, etc..'],
        ['driving_license', '0 = customer does not have DL, 1 = already have DL'],
        ['vehicle_age', 'vehicle age: < 1 Year, 1-2 Year, > 2 Years'],
        ['vehicle_damage', 'No = customer has never had their vehicle damaged in the past, Yes = has had it.'],
        ['vehicle_prev_insured', '0 = customer does not have vehicle insurance, 1= already has vehicle insurance.'],
        ['health_annual_premium', 'annual amount paid by the customer to the company for health insurance. Currency: Rs(Pakistani rupee, R$1.00 = ± Rs0.03).'],
        ['days_associated', 'number of days since the customer joined the company by purchasing health insurance. The policy is annual.'],
        ['response', '0 = customer is not interested, 1 = customer is interested.']
      ]
print(tabulate(tab_meanings, headers='firstrow', stralign='left', tablefmt='rst'))
# Out:
# =====================  =========================================================================================================================
# Column                 Meaning
# =====================  =========================================================================================================================
# id                     unique customer identifier.
# gender                 client gender: Male / Female.
# age                    customer age.
# region_code            customer region code.
# policy_sales_channel   Anonymized Code for the channel of outreaching to the customer. Ie: Over Mail, Over Phone, In Person, etc..
# driving_license        0 = customer does not have DL, 1 = already have DL
# vehicle_age            vehicle age: < 1 Year, 1-2 Year, > 2 Years
# vehicle_damage         No = customer has never had their vehicle damaged in the past, Yes = has had it.
# vehicle_prev_insured   0 = customer does not have vehicle insurance, 1= already has vehicle insurance.
# health_annual_premium  annual amount paid by the customer to the company for health insurance. Currency: Rs(Pakistani rupee, R$1.00 = ± Rs0.03).
# days_associated        number of days since the customer joined the company by purchasing health insurance. The policy is annual.
# response               0 = customer is not interested, 1 = customer is interested.
# =====================  =========================================================================================================================

# %% [markdown]
# ## 1.1. Organize columns

# %%
 # removing duplicated columns
df1 = df1.loc[:, ~ df1.columns.duplicated()]

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print( 'Number of Rows: {}'.format( df1.shape[0] ) )
print( 'Number of Cols: {}'.format( df1.shape[1] ) )
# Out:
# Number of Rows: 381109
# Number of Cols: 12

# %% [markdown]
# ## 1.3. Data Types

# %%
df1.dtypes
# Out:
# id                        int64
# gender                   object
# age                       int64
# region_code             float64
# policy_sales_channel    float64
# driving_license           int64
# vehicle_age              object
# vehicle_damage           object
# vehicle_prev_insured      int64
# health_annual_paid      float64
# days_associated           int64
# response                  int64
# dtype: object

# %%
#convert df['region_code'] to int:
df1['region_code'] = df1['region_code'].astype(int)
df1['region_code'].head()
# Out:
# 0    11
# 1    15
# 2    35
# 3     8
# 4     8
# Name: region_code, dtype: int64

# %%
 #convert df['policy_sales_channel'] to int:
#df['policy_sales_channel'].value_counts().head(50)
df1['policy_sales_channel'] = df1['policy_sales_channel'].astype(int)
df1['policy_sales_channel'].head()
# Out:
# 0    152
# 1     14
# 2    152
# 3    160
# 4    124
# Name: policy_sales_channel, dtype: int64

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# region_code             0
# policy_sales_channel    0
# driving_license         0
# vehicle_age             0
# vehicle_damage          0
# vehicle_prev_insured    0
# health_annual_paid      0
# days_associated         0
# response                0
# dtype: int64

# %% [markdown]
# ## 1.5. Data Descriptive

# %%
# num_attributes = df1.select_dtypes(include=['int64', 'float64'])
# cat_attributes = df1.select_dtypes(exclude=['int64', 'float64','datetime64[ns]'])
#separate cathegorical and numerical attributes
num_attributes = df1[['age','health_annual_paid','days_associated']]
cat_attributes = df1[['gender','region_code','policy_sales_channel','driving_license', 'vehicle_age', 'vehicle_damage', 'vehicle_prev_insured', 'response']]

# %% [markdown]
# ### 1.5.1. Numerical Attributes

# %%
descriptive_stats(num_attributes)
# Out:
#            attributes           min             max           range  \
# 0                 age   20.00000000     85.00000000     65.00000000
# 1  health_annual_paid 2630.00000000 540165.00000000 537535.00000000
# 2     days_associated   10.00000000    299.00000000    289.00000000
#
#             mean         median            std       skew    kurtosis
# 0    38.82258357    36.00000000    15.51159067 0.67253900 -0.56565507
# 1 30564.38958146 31669.00000000 17213.13247397 1.76608721 34.00456870
# 2   154.34739668   154.00000000    83.67119385 0.00302952 -1.20068804

# %%
 #Num Attributes plot
plt.figure(figsize=(20,14))

plt.subplot(3,3,1)
age_hist = sns.histplot(df1['age'], binwidth=1, kde=True);
age_hist.set_ylabel('Customers')
age_hist.set_xlabel('Age')
age_hist.set_title('Customers by Age');

plt.subplot(3,3,2)
hap_hist = sns.histplot(df1['health_annual_paid'], kde=True);
hap_hist.set_ylabel('Customers')
hap_hist.set_xlabel('Health Annual Paid')
hap_hist.set_title('Customers by Health Annual Paid');

plt.subplot(3,3,3)
da_hist = sns.histplot(df1['days_associated'], binwidth=1, kde=True);
da_hist.set_ylabel('Customers')
da_hist.set_xlabel('Days Associated')
da_hist.set_title('Customers by Days Associated');

# %% [markdown]
#  Highlights:
# - age: mean = 36y, 1 std = 15.5  -->  68% of ages are between 20,5 and 51,5
# - yhealth_annual_premium: very big range of 537535, high kurtosis, many extreme values.
# - days_associated: very uniform, probably will not help much.

# %% [markdown]
# ### 1.5.2. Categorical Attributes

# %%
#variations of each column
print(f"- Distinct values:\n{cat_attributes.apply( lambda x: x.unique().shape[0] ) } \n" )
print(f"- Variations:\n{cat_attributes.apply( lambda x: x.unique() ) } " )
# Out:
# - Distinct values:
# gender                    2
# region_code              53
# policy_sales_channel    155
# driving_license           2
# vehicle_age               3
# vehicle_damage            2
# vehicle_prev_insured      2
# response                  2
# dtype: int64
#
# - Variations:
# gender                                                     [Male, Female]
# region_code             [11, 15, 35, 8, 28, 39, 29, 30, 25, 22, 36, 0,...
# policy_sales_channel    [152, 14, 160, 124, 13, 26, 151, 157, 156, 122...
# driving_license                                                    [1, 0]
# vehicle_age                               [< 1 Year, 1-2 Year, > 2 Years]
# vehicle_damage                                                  [Yes, No]
# vehicle_prev_insured                                               [0, 1]
# response                                                           [0, 1]
# dtype: object

# %%
plt.figure(figsize=(16,12))

plt.subplot (3,3,1)
sns.countplot (x = cat_attributes['gender']);

plt.subplot (3,3,2)
sns.countplot (x = cat_attributes['region_code']);

plt.subplot (3,3,3)
sns.countplot (x = cat_attributes['driving_license']);
plt.xticks([0,1],['No','Yes']);

plt.subplot (3,3,4)
sns.countplot (x = cat_attributes['vehicle_age']);

plt.subplot (3,3,5)
sns.countplot (x = cat_attributes['vehicle_damage']);

plt.subplot (3,3,6)
sns.countplot (x = cat_attributes['vehicle_prev_insured']);
plt.xticks([0,1],['No','Yes']);

plt.subplot (3,3,7)
sns.countplot (x = cat_attributes['response']);
plt.xticks([0,1],['No','Yes']);

# %%
round(cat_attributes['response'].value_counts(normalize=True) *100,2 )
# Out:
# 0   87.74000000
# 1   12.26000000
# Name: response, dtype: float64

# %% [markdown]
# ### Test Data Extraction

# %%
 # Test Dataset Extraction
X = df1.drop('response', axis = 1).copy()
y = df1['response'].copy()

x_train, x_test, y_train, y_test = ms.train_test_split(X, y, stratify = y, test_size = 0.20, random_state = 45)

# df2 is the new dataset, and will be used to train and validate the models
df2 = pd.concat([x_train, y_train], axis = 1)

# df_test is a separate dataset, and will be used to perfomr the final evaluation of the trained model
df_test = pd.concat([x_test, y_test], axis = 1)

# %%
 #Check test stratify
df_test['response'].value_counts() / df_test['response'].count()
# Out:
# 0   0.87743696
# 1   0.12256304
# Name: response, dtype: float64

# %%
#Check train stratify
df1['response'].value_counts() / df1['response'].count()
# Out:
# 0   0.87743664
# 1   0.12256336
# Name: response, dtype: float64

# %%
x_train.isna().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# region_code             0
# policy_sales_channel    0
# driving_license         0
# vehicle_age             0
# vehicle_damage          0
# vehicle_prev_insured    0
# health_annual_paid      0
# days_associated         0
# dtype: int64

# %% [markdown]
# # 2.0. Feature Engineering

# %%
df2 = df1.copy()

# %%
df2.head()
# Out:
#    id  gender  age  region_code  policy_sales_channel  driving_license  \
# 0   7    Male   23           11                   152                1
# 1  13  Female   41           15                    14                1
# 2  18  Female   25           35                   152                1
# 3  31  Female   26            8                   160                1
# 4  39    Male   45            8                   124                1
#
#   vehicle_age vehicle_damage  vehicle_prev_insured  health_annual_paid  \
# 0    < 1 Year            Yes                     0      23367.00000000
# 1    1-2 Year             No                     1      31409.00000000
# 2    < 1 Year             No                     1      46622.00000000
# 3    < 1 Year             No                     0       2630.00000000
# 4    1-2 Year            Yes                     0      42297.00000000
#
#    days_associated  response
# 0              249         0
# 1              221         0
# 2              299         0
# 3              136         0
# 4              264         0

# %%
df2['vehicle_age'].value_counts()
# Out:
# 1-2 Year     200316
# < 1 Year     164786
# > 2 Years     16007
# Name: vehicle_age, dtype: int64

# %%
dict_vehicle_age = { '> 2 Years':'over_2_years', '1-2 Year':'between_1_2_years', '< 1 Year': 'below_1_year' }
df2['vehicle_age'] = df2['vehicle_age'].map(dict_vehicle_age)
df2['vehicle_age'].value_counts()
# Out:
# between_1_2_years    200316
# below_1_year         164786
# over_2_years          16007
# Name: vehicle_age, dtype: int64

# %%
dict_vehicle_damage = {'Yes': 1, 'No':0}
df2['vehicle_damage'] = df2['vehicle_damage'].map(dict_vehicle_damage)
df2['vehicle_damage'].value_counts()
# Out:
# 1    192413
# 0    188696
# Name: vehicle_damage, dtype: int64

# %% [markdown]
# # 3.0. Data Filtering

# %%
df3 = df2.copy()

# %% [markdown]
# # 4.0. Exploratoria Data Analysis (EDA)

# %%
df4 = df3.copy()

# %%
# Generate report
report = sv.analyze(df4, target_feat='response')

# Save and show on browser
report.show_html(filepath='../reports/sweetviz_report.html',open_browser=True)
#Report ../reports/sweetviz_report.html was generated.
# Out:
#                                              |                                              | [  0%]   00:00 -…
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## 4.1. Univariate Analysis

# %%
df4.columns
# Out:
# Index(['id', 'gender', 'age', 'region_code', 'policy_sales_channel',
#        'driving_license', 'vehicle_age', 'vehicle_damage',
#        'previously_insured', 'annual_premium', 'vintage', 'response'],
#       dtype='object')

# %%
# age
sns.boxplot(x ='response' , y = 'age' , data=df4)
# Out:
# <AxesSubplot:xlabel='response', ylabel='age'>

# %%
aux00 = df4.loc[df4['response'] == 0,'age']
sns.histplot(aux00)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
aux00 = df4.loc[df4['response'] == 1,'age']
sns.histplot(aux00)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# annual_premium

aux = df4[df4['annual_premium'] < 80000]
sns.boxplot(x ='response' , y = 'annual_premium' , data=aux)
# Out:
# <AxesSubplot:xlabel='response', ylabel='annual_premium'>

# %%
aux = df4[(df4['annual_premium']  > 10000) & (df4['annual_premium'] < 80000)]
aux00 = aux.loc[df4['response'] == 0,'annual_premium']
sns.histplot(aux00)
# Out:
# <AxesSubplot:xlabel='annual_premium', ylabel='Count'>

# %%
aux = df4[(df4['annual_premium'] > 10000) & (df4['annual_premium'] < 80000)]
aux00 = aux.loc[df4['response'] == 1,'annual_premium']
sns.histplot(aux00)
# Out:
# <AxesSubplot:xlabel='annual_premium', ylabel='Count'>

# %%
# driving_license

aux = df4[['driving_license','response']].groupby('response').sum().reset_index()
aux.head()   
aux['driving_license_perc'] = aux['driving_license'] / aux['driving_license'].sum()
# sns.barplot(x ='response' , y = 'driving_license' , data=aux)

# %%
aux
# Out:
#    response  driving_license  driving_license_perc
# 0         0           300187            0.87707555
# 1         1            42072            0.12292445

# %%
# region_code

aux0 = df4[['id','region_code','response']].groupby(['region_code','response']).count().reset_index()


sns.scatterplot(x= 'region_code' , y='id' , hue='response' , data=aux0)
# Out:
# <AxesSubplot:xlabel='region_code', ylabel='id'>

# %%
# previously_insured

pd.crosstab(df4['previously_insured'],df4['response'] ).apply(lambda x: x / x.sum() , axis =1)
# Out:
# response                    0          1
# previously_insured
# 0                  0.77426071 0.22573929
# 1                  0.99905799 0.00094201

# %%
# vehicle_age

df4[['id','vehicle_age', 'response']].groupby( ['vehicle_age', 'response'] ).count().reset_index()
# Out:
#    vehicle_age  response      id
# 0            0         0  142025
# 1            0         1    6455
# 2            1         0  148749
# 3            1         1   31420
# 4            2         0   10114
# 5            2         1    4235

# %%
# policy_sales_channel

aux0 = df4[['policy_sales_channel','response']].groupby('policy_sales_channel').sum().reset_index()
sns.barplot(x ='response' , y= 'policy_sales_channel' , data=aux0)
# Out:
# <AxesSubplot:xlabel='response', ylabel='policy_sales_channel'>

# %%
# vintage


sns.boxplot(x ='response' , y = 'vintage' , data=df4)
# Out:
# <AxesSubplot:xlabel='response', ylabel='vintage'>

# %%
aux00 = df4.loc[df4['response'] == 0,'vintage']
sns.histplot(aux00)
# Out:
# <AxesSubplot:xlabel='vintage', ylabel='Count'>

# %%
aux00 = df4.loc[df4['response'] == 1,'vintage']
sns.histplot(aux00)
# Out:
# <AxesSubplot:xlabel='vintage', ylabel='Count'>

# %% [markdown]
# ## 4.2. Bivariate Analysis

# %% [markdown]
# ### H1) Interest is greater in customers with HIGHER AGE.

# %%
 # Distribution of interested by age
eda_age = sns.boxplot(x = 'response', y= 'age', data = df3)
eda_age.set_xticklabels(['No', 'Yes'])
eda_age.set_ylabel('Age')
eda_age.set_xlabel('Interest')
eda_age.set_title('Interested Customers by Age');

# %%
#mean age of interested
df3_resp_yes = df3[df3['response']==1]
round(df3_resp_yes['age'].mean() ,1)
# Out:
# 43.4

# %%
 # Analyse just interested customers by age
plt.figure(figsize=(15,6))
aux_age2 = df3[['age', 'response']].groupby('age').sum().reset_index()
eda_age2 = sns.barplot( x='age', y='response', data=aux_age2 )
eda_age2.set_title('Interested Customers by Age')
eda_age2.set_xlabel('Age')
eda_age2.set_ylabel('Interested')
plt.xticks( rotation=90 );

# %% [markdown]
# False hypothesis: Customers between 40-45 years old are the most interested in vehicle insurance.
# Interest in vehicle insurance decreases between 24-27 years old and after 44 years old.

# %% [markdown]
# ### H2) Interest is greater in FEMALE CUSTOMERS.

# %%
# Gender Interest Dashboard
#percentage of customers per gender
plt.figure(figsize=(12,6))
pie1_gen = plt.subplot (1,2,1)

pie1_gen.set_title('Customers by Gender')
perc_m, perc_f = df3['gender'].value_counts() / df3.shape[0] * 100
pie1_gen.pie([perc_m, perc_f], explode=(0, 0.1), labels=['Male', 'Female'], autopct='%1.1f%%', shadow=True, startangle=90)

#interested customers per gender
bar_gen = plt.subplot (1,2,2)

# labels
gen_true = df3.loc[df3['response'] == True]
gen_res = sns.countplot(x=gen_true['gender'],
                   order=gen_true['gender'].value_counts(ascending=False).index);
abs_values = gen_true['gender'].value_counts(ascending=False)    
rel_values = gen_true['gender'].value_counts(ascending=False, normalize=True).values * 100

lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]
gen_res.bar_label(container=gen_res.containers[0], labels=lbls);

bar_gen.set_title('Interested Customers by Gender')
bar_gen.set_xlabel('Gender')
bar_gen.set_ylabel('Interested customers')
plt.tight_layout(pad=4)

# %% [markdown]
# False hypothesis: 54% of customers are male, and 61% of interested customers in vehicle insurance are male.

# %% [markdown]
# ### H3) Interest is greater in customers WITH MOST RECENT VEHICLE AGE.

# %%
plt.rcParams["figure.figsize"] = (20, 7)

plt.subplot (1,3,1)
h3_df_below = df3.loc[df3['vehicle_age'] == 'below_1_year']
h3_int_below = h3_df_below[['vehicle_age', 'response']].groupby('response').count().reset_index()
fig_below_h3 = sns.barplot (x = 'response', y='vehicle_age', data=h3_int_below);
fig_below_h3.set_xlabel('Interest in Vehicle Insurance')
fig_below_h3.set_ylabel('Number of customers')
fig_below_h3.set_title('Interest in Vehicle Insurance when vehicle Age < 1 year');
fig_below_h3.set_xticklabels(['No', 'Yes']);

plt.subplot (1,3,2)
h3_df_between = df3.loc[df3['vehicle_age'] == 'between_1_2_years']
h3_int_between = h3_df_between[['vehicle_age', 'response']].groupby('response').count().reset_index()
fig_between_h3 = sns.barplot (x = 'response', y='vehicle_age', data=h3_int_between);
fig_between_h3.set_xlabel('Interest in Vehicle Insurance')
fig_between_h3.set_ylabel('Number of customers')
fig_between_h3.set_title('Interest in Vehicle Insurance when vehicle Age between 1 - 2 years');

fig_between_h3.set_xticklabels(['No', 'Yes']);

plt.subplot (1,3,3)
h3_df_over = df3.loc[df3['vehicle_age'] == 'over_2_years']
h3_int_over = h3_df_over[['vehicle_age', 'response']].groupby('response').count().reset_index()

fig_over_h3 = sns.barplot (x = 'response', y='vehicle_age', data=h3_int_over);
fig_over_h3.set_xlabel('Interest in Vehicle Insurance')
fig_over_h3.set_ylabel('Number of customers')
fig_over_h3.set_title('Interest in Vehicle Insurance when vehicle Age > 2 years');

fig_over_h3.set_xticklabels(['No', 'Yes']);

# %%
 # 4% of customers with vehicles below 1 year are interested
h3_df_below['response'].value_counts() / h3_df_below['response'].shape[0] *100
# Out:
# 0   95.62948309
# 1    4.37051691
# Name: response, dtype: float64

# %%
 # 17% of customers with vehicles between 1 and 2 years are interested
h3_df_between['response'].value_counts() / h3_df_between['response'].shape[0] *100
# Out:
# 0   82.62445336
# 1   17.37554664
# Name: response, dtype: float64

# %%
 # 29% of customers with vehicles over 2 years are interested
h3_df_over['response'].value_counts() / h3_df_over['response'].shape[0] *100
# Out:
# 0   70.62535141
# 1   29.37464859
# Name: response, dtype: float64

# %% [markdown]
# False hypothesis: interest is greater in customers with older vehicle age:
# - 29% of customers with vehicles over 2 years are interested.
# - 17% of customers with vehicles between 1 and 2 years are interested.
# - 4% of customers with vehicles below 1 year are interested.

# %% [markdown]
# ### H4) Interest is greater in customers who HAD VEHICLE DAMAGE.

# %%
 #vehicle_damage == 0(no): interested / not interested
plt.subplot (1,2,1)
h4_df_not_damaged = df3.loc[df3['vehicle_damage'] == 0]
h4_int_not_damaged = h4_df_not_damaged[['vehicle_damage', 'response']].groupby('response').count().reset_index()
fig_not_damaged_h4 = sns.barplot (x = 'response', y='vehicle_damage', data=h4_int_not_damaged);
fig_not_damaged_h4.set_xlabel('Interested in Vehicle Insurance')
fig_not_damaged_h4.set_ylabel('Number of customers')
fig_not_damaged_h4.set_title('Interest in Vehicle Insurance when customer didn\'t have Vehicle Damage');
fig_not_damaged_h4.set_xticklabels(['No', 'Yes']);

#vehicle_damage == 1(yes): interested / not interested
plt.subplot (1,2,2)
h4_df_damaged = df3.loc[df3['vehicle_damage'] == 1]
h4_int_damaged = h4_df_damaged[['vehicle_damage', 'response']].groupby('response').count().reset_index()
fig_damaged_h4 = sns.barplot (x = 'response', y='vehicle_damage', data=h4_int_damaged);
fig_damaged_h4.set_xlabel('Interested in Vehicle Insurance')
fig_damaged_h4.set_ylabel('Number of customers')
fig_damaged_h4.set_title('Interest in Vehicle Insurance when customer had Vehicle Damage');
fig_damaged_h4.set_xticklabels(['No', 'Yes']);

# %%
# Only 0.5% of customers how didn't have vehicle damage are interestet in vehicle insurance
h4_df_not_damaged['response'].value_counts() / h4_df_not_damaged.shape[0] *100
# Out:
# 0   99.47958621
# 1    0.52041379
# Name: response, dtype: float64

# %%
# 24% of customers how had vehicle damage are interested in vehicle insurance
h4_df_damaged['response'].value_counts() / h4_df_damaged.shape[0] *100
# Out:
# 0   76.23445401
# 1   23.76554599
# Name: response, dtype: float64

# %% [markdown]
# True hypothesis: 24% of customers how had vehicle damage are interested in vehicle insurance, while only 0.5% of those who didn't have vehicle damage are interestet.

# %% [markdown]
# ### H5) Interest is greater in Customers who HAD VEHICLE PREVIOUSLY INSURED.

# %%
#vehicle_previously_insured == 1(yes): interested / not interested
plt.subplot (1,2,1)
h5_df_insured = df3.loc[df3['vehicle_prev_insured'] == 1]
h5_int_insured = h5_df_insured[['vehicle_prev_insured', 'response']].groupby('response').count().reset_index()
fig_insured_h5 = sns.barplot (x = 'response', y='vehicle_prev_insured', data=h5_int_insured);
fig_insured_h5.set_xlabel('Interested in Vehicle Insurance')
fig_insured_h5.set_ylabel('Number of customers')
fig_insured_h5.set_title('Interest in Vehicle Insurance when customer had Vehicle Insurance');
fig_insured_h5.set_xticklabels(['No', 'Yes']);

#vehicle_previously_insured == 0(no): interested / not interested
plt.subplot (1,2,2)
h5_df_not_insured = df3.loc[df3['vehicle_prev_insured'] == 0]
h5_int_not_insured = h5_df_not_insured[['vehicle_prev_insured', 'response']].groupby('response').count().reset_index()
fig_not_insured_h5 = sns.barplot (x = 'response', y='vehicle_prev_insured', data=h5_int_not_insured);
fig_not_insured_h5.set_xlabel('Interested in Vehicle Insurance')
fig_not_insured_h5.set_ylabel('Number of customers')
fig_not_insured_h5.set_title('Interest in Vehicle Insurance when customer didn\'t have Vehicle Insurance');
fig_not_insured_h5.set_xticklabels(['No', 'Yes']);

# %%
 #1% of customers who had vehicle previously insured are interested in vehicle insurance.
h5_df_insured['response'].value_counts() / h5_df_insured['response'].shape[0] *100
# Out:
# 0   99.90952196
# 1    0.09047804
# Name: response, dtype: float64

# %%
 #22% of customers who didn't have vehicle previously insured are interested in vehicle insurance.
h5_df_not_insured['response'].value_counts() / h5_df_not_insured['response'].shape[0] *100
# Out:
# 0   77.45458420
# 1   22.54541580
# Name: response, dtype: float64

# %% [markdown]
#  False hypothesis: 22% of customers who didn't have vehicle previously insured are interested in vehicle insurance, while only 1% of customers who had vehicle previously insured are interested.

# %% [markdown]
# ### H6) Interest is greater in customers with HIGHER ANNUAL HEALTH EXPANSES.

# %%
 aux_h6 = df3[['health_annual_paid', 'response']].groupby('response').count().reset_index()
fig_h6 = sns.regplot (x= 'health_annual_paid', y='response', data=aux_h6)
fig_h6.set_xlabel('Anuual Health Expanses');
fig_h6.set_ylabel('Interested (1) / Not interested (0)')
fig_h6.set_title('Interest in Vehicle Insurance vs annual health expances');

# %% [markdown]
# False hypothesis: There is a decrease on interest of a vehicle insurance on higher annual health expenses.

# %% [markdown]
# ### H7) Interest is greater in customers whth MORE DAYS ASSOCIATED.

# %%
# get just the interested customers
aux_h7 = df3[['days_associated', 'response']].groupby('days_associated').sum().reset_index()
fig_h7 = sns.regplot (x= 'days_associated', y='response', data=aux_h7)
fig_h7.set_xlabel('Days Associated');
fig_h7.set_ylabel('Number of Interested Customers')
fig_h7.set_title('Interest in Vehicle Insurance vs Days Associated');

# %% [markdown]
# False hypothesis: Customers with more days of health insurance (more days associated) have a bit less interest in vehicle insurance.

# %% [markdown]
# ### Hypothesis conclusion

# %%
#hypothesis tab
hyp_tab = [['Hypoteses', 'Conclusion', 'Estimated Relevance'],
       ['H1 - Interest is greater in customers with HIGHER AGE.', 'False', 'Medium'],
       ['H2 - Interest is greater in FEMALE CUSTOMERS.', 'False', 'Low'],
       ['H3 - Interest is greater in customers WITH MOST RECENT VEHICLE AGE.', 'False', 'High'],
       ['H4 - Interest is greater in customers who HAD VEHICLE DAMAGE.', 'True', 'High'],
       ['H5 - Interest is greater in Customers who HAD VEHICLE PREVIOUSLY INSURED.', 'False', 'High'],
       ['H6 - Interest is greater in customers with HIGHER ANNUAL HEALTH EXPANSES.', 'False', 'Low'],
       ['H7 - Interest is greater in customers whth MORE DAYS ASSOCIATED', 'False', 'Low'],
      ]
print(tabulate(hyp_tab, headers='firstrow', stralign='left', tablefmt='rst'))
# Out:
# =========================================================================  ============  =====================
# Hypoteses                                                                  Conclusion    Estimated Relevance
# =========================================================================  ============  =====================
# H1 - Interest is greater in customers with HIGHER AGE.                     False         Medium
# H2 - Interest is greater in FEMALE CUSTOMERS.                              False         Low
# H3 - Interest is greater in customers WITH MOST RECENT VEHICLE AGE.        False         High
# H4 - Interest is greater in customers who HAD VEHICLE DAMAGE.              True          High
# H5 - Interest is greater in Customers who HAD VEHICLE PREVIOUSLY INSURED.  False         High
# H6 - Interest is greater in customers with HIGHER ANNUAL HEALTH EXPANSES.  False         Low
# H7 - Interest is greater in customers whth MORE DAYS ASSOCIATED            False         Low
# =========================================================================  ============  =====================

# %% [markdown]
# # 5.0. Data Preparation

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1. Standardization

# %%
#health_annual_paid -> StandardScaler

ss = pp.StandardScaler()

df5['health_annual_paid'] = ss.fit_transform( df5[['health_annual_paid']].values )
pickle.dump (ss, open ('../src/features/health_annual_paid_scaler.pkl', 'wb') )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 5>()
#       1 #health_annual_paid -> StandardScaler
#       3 ss = pp.StandardScaler()
# ----> 5 df5['health_annual_paid'] = ss.fit_transform( df5[['health_annual_paid']].values )
#       6 pickle.dump (ss, open ('../src/features/health_annual_paid_scaler.pkl', 'wb') )
#
# NameError: name 'df5' is not defined

# %% [markdown]
# ## 5.2. Rescaling

# %%
# MinMaxScaler (few outliers)
mms_age = pp.MinMaxScaler()
mms_days_assoc = pp.MinMaxScaler()

#age
df5['age'] = mms_age.fit_transform( df5[['age']].values )
pickle.dump (mms_age, open ('../src/features/age_scaler.pkl', 'wb') )

#days_associated
df4['days_associated'] = mms_days_assoc.fit_transform( df5[['days_associated']].values )
pickle.dump (mms_days_assoc, open ('../src/features/days_assoc_scaler.pkl', 'wb') )

# %% [markdown]
# ## 5.3. Encoder

# %%
#gender: one hot encoder / target encoder (let's use target encoding)
gender_target_encoder = df5.groupby('gender')['response'].mean()
df5.loc[:,'gender'] = df5['gender'].map(gender_target_encoder)
pickle.dump (gender_target_encoder, open ('../src/features/gender_target_encoder.pkl', 'wb') )

#region_code: requency encoding / target encoding / weighted target encoding  (let's use target encoding)
region_code_target_encoder = df5.groupby('region_code')['response'].mean()
df5.loc[:,'region_code'] = df5['region_code'].map(region_code_target_encoder)
pickle.dump (region_code_target_encoder, open ('../src/features/region_code_target_encoder.pkl', 'wb') )

#vehicle_age: one hot encoding / Label Encoding / frequency encoding (let's use one hot encoding)
df5 = pd.get_dummies( df5, prefix='vehicle_age', columns=['vehicle_age'] )

#policy_sales_channel: frequency encoding / target encoding (let's use frequency encoding)
policy_sales_freq_encoder = df5.groupby('policy_sales_channel').size() / len (df5)
df5.loc[:,'policy_sales_channel'] = df5['policy_sales_channel'].map(policy_sales_freq_encoder)
pickle.dump (policy_sales_freq_encoder, open ('../src/features/policy_sales_freq_encoder.pkl', 'wb') )

# %%
df5.head()
# Out:
#             id     gender        age  region_code  policy_sales_channel  \
# 332417  371361 0.10395177 0.49230769   0.18673594            0.19391775
# 318002  255092 0.13836348 0.04615385   0.06736712            0.00761266
# 192366   12237 0.13836348 0.21538462   0.18673594            0.20926442
# 126655  248977 0.10395177 0.40000000   0.07221130            0.00165635
# 318534  259597 0.13836348 0.46153846   0.09660333            0.19391775
#
#         driving_license  vehicle_damage  vehicle_prev_insured  \
# 332417                1               1                     0
# 318002                1               1                     0
# 192366                1               1                     0
# 126655                1               1                     0
# 318534                1               1                     0
#
#         health_annual_paid  days_associated  response  vehicle_age_1-2 Year  \
# 332417         -0.31896604               68         0                     1
# 318002         -0.12918375              182         0                     0
# 192366         -0.33761417               10         0                     1
# 126655          0.58685782              253         0                     1
# 318534          0.44867639               72         0                     1
#
#         vehicle_age_< 1 Year  vehicle_age_> 2 Years
# 332417                     0                      0
# 318002                     1                      0
# 192366                     0                      0
# 126655                     0                      0
# 318534                     0                      0

# %% [markdown]
# ### Test Preparation

# %% [markdown]
# Replicate the transformation done in Training(df5) to x_test dataset.

# %%
#load x_test and y_test from test data.

x_test = df_test
y_test = x_test['response']
x_test = x_test.drop('response', axis=1)
x_test.head()
# Out:
#             id  gender  age  region_code  policy_sales_channel  \
# 274973  291687    Male   37           15                   152
# 228952  304213    Male   27           15                   152
# 183928  327081  Female   64           28                    13
# 272592  272375    Male   21           25                   152
# 24869   198591  Female   26           47                   152
#
#         driving_license vehicle_age vehicle_damage  vehicle_prev_insured  \
# 274973                1    1-2 Year             No                     1
# 228952                1    < 1 Year             No                     1
# 183928                1    1-2 Year            Yes                     0
# 272592                1    < 1 Year             No                     1
# 24869                 1    < 1 Year            Yes                     0
#
#         health_annual_paid  days_associated
# 274973       2630.00000000              176
# 228952       2630.00000000               22
# 183928      61283.00000000              281
# 272592       2630.00000000              133
# 24869       31600.00000000              279

# %%
y_test.head()
# Out:
# 274973    0
# 228952    0
# 183928    0
# 272592    0
# 24869     0
# Name: response, dtype: int64

# %%
ss = pp.StandardScaler()
mms_age = pp.MinMaxScaler()
mms_days_assoc = pp.MinMaxScaler()

# %%
# ----- Feature Engeneering ----- dict_vehicle_age
#vehicle_damage
x_test['vehicle_damage'] = x_test['vehicle_damage'].map(dict_vehicle_damage)
#vehicle_age
x_test['vehicle_age'] = x_test['vehicle_age'].map(dict_vehicle_age)

# ----- Data Preparation - Standardization ----- 
#health_annual_paid: StandardScaler
x_test['health_annual_paid'] = ss.fit_transform(x_test[['health_annual_paid']].values)
    #If we used fit_transform() on our test data too, we would compute a new mean and variance, that is a new scale for each feature, and would let our model learn about our test data too. Using transform() we use the same mean and variance as it is calculated from our training data to transform our test data.

# ----- Data Preparation - Rescaling ----- 
#age: MinMaxScaler
x_test['age'] = mms_age.fit_transform( x_test[['age']].values )
#days_associated: MinMaxScaler
x_test['days_associated'] = mms_days_assoc.fit_transform( x_test[['days_associated']].values )

# ----- Data Preparation - Encoding ----- 
#vehicle_age: one hot encoding 
x_test = pd.get_dummies( x_test, prefix='vehicle_age', columns=['vehicle_age'] ) 
#gender: target encoding
x_test.loc[:,'gender'] = x_test.loc[:,'gender'].map(gender_target_encoder)
#region_code: target encoding
x_test.loc[:,'region_code'] = x_test.loc[:,'region_code'].map(region_code_target_encoder)
#policy_sales_channel: frequency encoding
x_test.loc[:,'policy_sales_channel'] = x_test['policy_sales_channel'].map(policy_sales_freq_encoder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 22>()
#      20 x_test = pd.get_dummies( x_test, prefix='vehicle_age', columns=['vehicle_age'] )
#      21 #gender: target encoding
# ---> 22 x_test.loc[:,'gender'] = x_test.loc[:,'gender'].map(gender_target_encoder)
#      23 #region_code: target encoding
#      24 x_test.loc[:,'region_code'] = x_test.loc[:,'region_code'].map(region_code_target_encoder)
#
# NameError: name 'gender_target_encoder' is not defined

# %%
x_test.head()
# Out:
#             id     gender         age  region_code  policy_sales_channel  \
# 274973  291687 0.13836348 37.00000000   0.07221130            0.35352770
# 228952  304213 0.13836348 27.00000000   0.07221130            0.35352770
# 183928  327081 0.10395177 64.00000000   0.18673594            0.00480506
# 272592  272375 0.13836348 21.00000000   0.03964321            0.35352770
# 24869   198591 0.10395177 26.00000000   0.08855219            0.35352770
#
#         driving_license  vehicle_damage  vehicle_prev_insured  \
# 274973                1               0                     1
# 228952                1               0                     1
# 183928                1               1                     0
# 272592                1               0                     1
# 24869                 1               1                     0
#
#         health_annual_paid  days_associated  vehicle_age_below_1_year  \
# 274973         -1.61663213       0.57439446                         0
# 228952         -1.61663213       0.04152249                         1
# 183928          1.78016392       0.93771626                         0
# 272592         -1.61663213       0.42560554                         1
# 24869           0.06111976       0.93079585                         1
#
#         vehicle_age_between_1_2_years  vehicle_age_over_2_years
# 274973                              1                         0
# 228952                              0                         0
# 183928                              1                         0
# 272592                              0                         0
# 24869                               0                         0

# %%
x_test.isna().sum()
# Out:
# id                               0
# gender                           0
# age                              0
# region_code                      0
# policy_sales_channel             0
# driving_license                  0
# vehicle_damage                   0
# vehicle_prev_insured             0
# health_annual_paid               0
# days_associated                  0
# vehicle_age_below_1_year         0
# vehicle_age_between_1_2_years    0
# vehicle_age_over_2_years         0
# dtype: int64

# %%
# Check the rows with NaN
x_test.loc[x_test['policy_sales_channel'].isna()]
# Out:
#             id     gender         age  region_code  policy_sales_channel  \
# 321126  279715 0.13836348 67.00000000   0.18673594                   NaN
# 373988  324174 0.13836348 74.00000000   0.06998069                   NaN
#
#         driving_license  vehicle_damage  vehicle_prev_insured  \
# 321126                1               0                     1
# 373988                1               1                     0
#
#         health_annual_paid  days_associated  vehicle_age_below_1_year  \
# 321126          0.15586612       0.96885813                         0
# 373988         -1.61663213       0.01730104                         0
#
#         vehicle_age_between_1_2_years  vehicle_age_over_2_years
# 321126                              1                         0
# 373988                              1                         0

# %%
 # Remove these indexes on x_test
x_test = x_test.drop(index = [321126,373988])
x_test.shape
# Out:
# (76220, 13)

# %%
 # Remove these indexes on y_test
y_test = y_test.drop(index = [321126,373988] )
y_test.shape
# Out:
# (76220,)

# %%
#Export Training
df5.to_csv(datapath+'df4_data_prep_done.csv') #contains x_train + y_train
#Export Test
x_test.to_csv(datapath+'x_test.csv') #x_test
y_test.to_csv(datapath+'y_test.csv') #y_test

# %% [markdown]
# # 6.0. Feature Selection

# %%
df6 = df5.copy()

# %% [markdown]
# ### Validation Split

# %% [markdown]
# Perform a new data split, now extracting Validation from Training (df5).

# %%
X = df6.drop(['response', 'id'], axis = 1).copy() # 304887 rows × 12 columns
y = df6['response'].copy() #Length: 304887

#Split Train into Val:
x_train, x_val, y_train, y_val = ms.train_test_split(X, y, stratify = y, test_size=0.10, random_state = 45)

# %%
 #check split
print('x_train -> ',x_train.shape)
print('y_train -> ',y_train.shape)
print('x_val   -> ',x_val.shape)
print('y_val   -> ',y_val.shape)
# Out:
# x_train ->  (274398, 12)
# y_train ->  (274398,)
# x_val   ->  (30489, 12)
# y_val   ->  (30489,)

# %% [markdown]
# ## 6.1. Feature Importancia

# %%
# model definition
forest = en.ExtraTreesClassifier(n_estimators=250, random_state=0, n_jobs=-1)

# data preparation
x_train_n = x_train # (274398 rows × 12 columns)
y_train_n = y_train.values #(274398 rows)
forest.fit( x_train_n, y_train_n )
# Out:
# ExtraTreesClassifier(n_estimators=250, n_jobs=-1, random_state=0)

# %%
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_] , axis= 0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print('Feature ranking: ')
df =pd.DataFrame()
for i, j in zip(x_train_n, forest.feature_importances_):
    aux = pd.DataFrame({'feature': i, 'importances': j}, index=[0])
    df = pd.concat([df,aux], axis = 0)
    
print(df.sort_values('importances', ascending= False))
    
# Plot tge umpurity-based feature importances of the forest
plt.figure()
plt.title("Feature Importances")
plt.bar(range(x_train_n.shape[1]), importances[indices], color= 'r', yerr= std[indices], align= 'center')
plt.xticks(range(x_train_n.shape[1]), indices)
plt.xlim([-1, x_train_n.shape[1]])
plt.show()
# Out:
# Feature ranking:
#                  feature  importances
# 0        days_associated   0.27290073
# 0     health_annual_paid   0.24310449
# 0                    age   0.16416109
# 0            region_code   0.10653055
# 0         vehicle_damage   0.06690571
# 0   policy_sales_channel   0.06091446
# 0   vehicle_prev_insured   0.05748596
# 0   vehicle_age_< 1 Year   0.01228510
# 0   vehicle_age_1-2 Year   0.00764060
# 0                 gender   0.00510275
# 0  vehicle_age_> 2 Years   0.00246182
# 0        driving_license   0.00050673

# %% [markdown]
# # 7.0. Machine Learning Modelling

# %%
df7 = df6.copy()

# %%
 cols_selected = ['days_associated','health_annual_paid','age','region_code',
                 'vehicle_damage','policy_sales_channel', 'vehicle_prev_insured']

#new x data, only with cols selected:
x_train = x_train[ cols_selected ]
x_val = x_val[ cols_selected ]

# %%
 x_train
# Out:
#         days_associated  health_annual_paid        age  region_code  \
# 338532              129         -0.16219441 0.04615385   0.07436988
# 255428              288          0.32810064 0.43076923   0.12987505
# 186404              293          0.31159532 0.03076923   0.08855219
# 192264              156          3.72703949 0.69230769   0.18673594
# 59130               291          0.44259548 0.07692308   0.07995418
# ...                 ...                 ...        ...          ...
# 328165              204         -0.36616548 0.04615385   0.11918228
# 359835              185         -0.35469863 0.07692308   0.08855219
# 213093              255          0.06581074 0.15384615   0.18673594
# 245898               62         -1.61663213 0.06153846   0.07221130
# 297575               11         -1.61663213 0.64615385   0.11343416
#
#         vehicle_damage  policy_sales_channel  vehicle_prev_insured
# 338532               0            0.35352770                     1
# 255428               1            0.19391775                     0
# 186404               0            0.35352770                     1
# 192264               1            0.20926442                     0
# 59130                0            0.35352770                     0
# ...                ...                   ...                   ...
# 328165               0            0.35352770                     1
# 359835               0            0.35352770                     1
# 213093               1            0.19391775                     0
# 245898               1            0.35352770                     0
# 297575               1            0.01745237                     0
#
# [274398 rows x 7 columns]

# %%
y_val
# Out:
# 357009    0
# 124985    0
# 352809    0
# 16666     0
# 303438    1
#          ..
# 106706    1
# 216249    0
# 255478    0
# 305621    0
# 51563     0
# Name: response, Length: 30489, dtype: int64

# %%
#Export Training w/ sel features
x_train.to_csv(datapath+'x_train.csv')
y_train.to_csv(datapath+'y_train.csv')

#Export Validation w/ sel features
x_val.to_csv(datapath+'x_val.csv')
y_val.to_csv(datapath+'y_val.csv')

# %%
#train
x_train = pd.read_csv(datapath+'x_train.csv', index_col=0)
y_train = pd.read_csv(datapath+'y_train.csv', index_col=0)

#validation
x_val = pd.read_csv(datapath+'x_val.csv', index_col=0)
y_val = pd.read_csv(datapath+'y_val.csv', index_col=0)

# %% [markdown]
# ### KNN

# %%
# Model definition
knn_model = nh.KNeighborsClassifier( n_neighbors=8 )
# Model training
knn_model.fit( x_train, y_train.values.ravel() )
# Model prediction (proba)
yhat_proba_knn = knn_model.predict_proba( x_val );

# %% [markdown]
# ### Cumulative Gain and Lift Curve

# %%
table_knn = gain_lift_curve(yhat_proba_knn, y_val, size = (10,12))

# %% [markdown]
# ### Precision@k and Recall@k

# %%
metrics_knn, new_table_knn = precision_recall_at_k(table_knn, 12200) #k = 12200 = 40% of customers

# %%
new_table_knn
# Out:
#                0          1  target correct  propensity_score  \
# 0     0.00000000 1.00000000       0      no        0.00000000
# 1     0.12500000 0.87500000       0      no        0.00000000
# 2     0.12500000 0.87500000       0      no        0.00000000
# 3     0.12500000 0.87500000       0      no        0.00000000
# 4     0.12500000 0.87500000       0      no        0.00000000
# ...          ...        ...     ...     ...               ...
# 30484 1.00000000 0.00000000       0     yes        0.00000000
# 30485 1.00000000 0.00000000       0     yes        0.00000000
# 30486 1.00000000 0.00000000       0     yes        0.00000000
# 30487 1.00000000 0.00000000       0     yes        0.00000000
# 30488 1.00000000 0.00000000       0     yes        0.00000000
#
#        cumulative_propensity_score  cumulative_porc_base       lift  ranking  \
# 0                       0.00000000            0.00003280 0.00000000        1
# 1                       0.00000000            0.00006560 0.00000000        2
# 2                       0.00000000            0.00009840 0.00000000        3
# 3                       0.00000000            0.00013119 0.00000000        4
# 4                       0.00000000            0.00016399 0.00000000        5
# ...                            ...                   ...        ...      ...
# 30484                   1.00000000            0.99986881 1.00013121    30485
# 30485                   1.00000000            0.99990160 1.00009841    30486
# 30486                   1.00000000            0.99993440 1.00006560    30487
# 30487                   1.00000000            0.99996720 1.00003280    30488
# 30488                   1.00000000            1.00000000 1.00000000    30489
#
#        precision_at_k  recall_at_k
# 0          0.00000000   0.00000000
# 1          0.00000000   0.00000000
# 2          0.00000000   0.00000000
# 3          0.00000000   0.00000000
# 4          0.00000000   0.00000000
# ...               ...          ...
# 30484      0.12258488   1.00000000
# 30485      0.12258086   1.00000000
# 30486      0.12257684   1.00000000
# 30487      0.12257282   1.00000000
# 30488      0.12256880   1.00000000
#
# [30489 rows x 11 columns]

# %%
#There are 3737 of 12200 rows with class 1 target feature, so the max precision that can be obtained is ~30% (3737/12200)
display(y_val.value_counts())
# Out:
# response
# 0           26752
# 1            3737
# dtype: int64

# %%
print(f"KNN - \nPrecision at 40% of base(k): {round( metrics_knn[0] ,2)}\nRecall at 40% of base(k): {round( metrics_knn[1] ,2) }")
# Out:
# KNN -
# Precision at 40% of base(k): 0.25
# Recall at 40% of base(k): 0.82

# %% [markdown]
# ### CatBoost

# %%
# Model definition
catboost = cb( random_state=42, verbose=False )
# Model training
catboost.fit( x_train, y_train.values.ravel() )
# Model prediction (proba)
yhat_proba_cb = catboost.predict_proba( x_val )

# %% [markdown]
# ### Cumulative Gain and Lift Curve

# %%
table_cb = gain_lift_curve(yhat_proba_cb, y_val, size = (10,12))

# %% [markdown]
# ### Precision@k and Recall@k

# %%
metrics_cb, new_table_cb = precision_recall_at_k(table_cb, 12200) #k = 12200 = 40% of customers

# %%
new_table_cb
# Out:
#                0          1  target correct  propensity_score  \
# 0     0.08796885 0.91203115       0      no        0.00000000
# 1     0.25695593 0.74304407       0      no        0.00000000
# 2     0.30892468 0.69107532       0      no        0.00000000
# 3     0.34389085 0.65610915       0      no        0.00000000
# 4     0.36557251 0.63442749       1     yes        0.00026759
# ...          ...        ...     ...     ...               ...
# 30484 0.99999947 0.00000053       0     yes        0.00000000
# 30485 0.99999953 0.00000047       0     yes        0.00000000
# 30486 0.99999956 0.00000044       0     yes        0.00000000
# 30487 0.99999981 0.00000019       0     yes        0.00000000
# 30488 0.99999984 0.00000016       0     yes        0.00000000
#
#        cumulative_propensity_score  cumulative_porc_base       lift  ranking  \
# 0                       0.00000000            0.00003280 0.00000000        1
# 1                       0.00000000            0.00006560 0.00000000        2
# 2                       0.00000000            0.00009840 0.00000000        3
# 3                       0.00000000            0.00013119 0.00000000        4
# 4                       0.00026759            0.00016399 1.63173669        5
# ...                            ...                   ...        ...      ...
# 30484                   1.00000000            0.99986881 1.00013121    30485
# 30485                   1.00000000            0.99990160 1.00009841    30486
# 30486                   1.00000000            0.99993440 1.00006560    30487
# 30487                   1.00000000            0.99996720 1.00003280    30488
# 30488                   1.00000000            1.00000000 1.00000000    30489
#
#        precision_at_k  recall_at_k
# 0          0.00000000   0.00000000
# 1          0.00000000   0.00000000
# 2          0.00000000   0.00000000
# 3          0.00000000   0.00000000
# 4          0.20000000   0.00026759
# ...               ...          ...
# 30484      0.12258488   1.00000000
# 30485      0.12258086   1.00000000
# 30486      0.12257684   1.00000000
# 30487      0.12257282   1.00000000
# 30488      0.12256880   1.00000000
#
# [30489 rows x 11 columns]

# %%
#There are 3737 of 12200 rows with class 1 target feature, so the max precision that can be obtained is ~30% (3737/12200)
display(y_val.value_counts())
# Out:
# response
# 0           26752
# 1            3737
# dtype: int64

# %%
print(f"Logistic Regression - \nPrecision at 40% of base(k): {round( metrics_cb[0] ,2)}\nRecall at 40% of base(k): {round( metrics_cb[1] ,2) }")
# Out:
# Logistic Regression -
# Precision at 40% of base(k): 0.28
# Recall at 40% of base(k): 0.92

# %% [markdown]
# ### Extra Trees

# %%
# model definition
et = en.ExtraTreesClassifier( n_estimators=100, random_state=30, n_jobs=-1 )
# model training
et.fit ( x_train, y_train.values.ravel() )
# Model prediction (proba)
yhat_proba_et = et.predict_proba(x_val)

# %% [markdown]
# ### Cumulative Gain and Lift Curve

# %%
table_et = gain_lift_curve(yhat_proba_et, y_val, size = (10,12))

# %% [markdown]
# ### Precision@k and Recall@k

# %%
metrics_et, new_table_et = precision_recall_at_k(table_et, 12200) #k = 12200 = 40% of customers

# %%
#full tabel et
new_table_et
# Out:
#                0          1  target correct  propensity_score  \
# 0     0.00000000 1.00000000       0      no        0.00000000
# 1     0.00000000 1.00000000       0      no        0.00000000
# 2     0.00000000 1.00000000       0      no        0.00000000
# 3     0.00000000 1.00000000       0      no        0.00000000
# 4     0.00000000 1.00000000       0      no        0.00000000
# ...          ...        ...     ...     ...               ...
# 30484 1.00000000 0.00000000       0     yes        0.00000000
# 30485 1.00000000 0.00000000       0     yes        0.00000000
# 30486 1.00000000 0.00000000       0     yes        0.00000000
# 30487 1.00000000 0.00000000       0     yes        0.00000000
# 30488 1.00000000 0.00000000       0     yes        0.00000000
#
#        cumulative_propensity_score  cumulative_porc_base       lift  ranking  \
# 0                       0.00000000            0.00003280 0.00000000        1
# 1                       0.00000000            0.00006560 0.00000000        2
# 2                       0.00000000            0.00009840 0.00000000        3
# 3                       0.00000000            0.00013119 0.00000000        4
# 4                       0.00000000            0.00016399 0.00000000        5
# ...                            ...                   ...        ...      ...
# 30484                   1.00000000            0.99986881 1.00013121    30485
# 30485                   1.00000000            0.99990160 1.00009841    30486
# 30486                   1.00000000            0.99993440 1.00006560    30487
# 30487                   1.00000000            0.99996720 1.00003280    30488
# 30488                   1.00000000            1.00000000 1.00000000    30489
#
#        precision_at_k  recall_at_k
# 0          0.00000000   0.00000000
# 1          0.00000000   0.00000000
# 2          0.00000000   0.00000000
# 3          0.00000000   0.00000000
# 4          0.00000000   0.00000000
# ...               ...          ...
# 30484      0.12258488   1.00000000
# 30485      0.12258086   1.00000000
# 30486      0.12257684   1.00000000
# 30487      0.12257282   1.00000000
# 30488      0.12256880   1.00000000
#
# [30489 rows x 11 columns]

# %%
 #There are 3737 of 12200 rows with class 1 target feature, so the max precision that can be obtained is ~30% (3737/12200)
display(y_val.value_counts())
# Out:
# response
# 0           26752
# 1            3737
# dtype: int64

# %%
print(f"Extra Trees - \nPrecision at 40% of base(k): {round( metrics_et[0] ,2)}\nRecall at 40% of base(k): {round( metrics_et[1] ,2) }")
# Out:
# Extra Trees -
# Precision at 40% of base(k): 0.27
# Recall at 40% of base(k): 0.88

# %% [markdown]
# ### XGBoost

# %%
xgb_model = XGBClassifier()

model_xgb = xgb_model.fit(x_train,y_train.values.ravel())

yhat_proba_xgb = model_xgb.predict_proba(x_val)
# Out:
# [13:57:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ### Cumulative Gain and Lift Curve

# %%
table_xgb = gain_lift_curve(yhat_proba_xgb, y_val, size = (10,12))

# %% [markdown]
# ### Precision@k and Recall@k

# %%
metrics_xgb, new_table_xgb = precision_recall_at_k(table_xgb, 12200) #k = 12200 = 40% of customers

# %%
 #full tabel XGB
new_table_xgb
# Out:
#                0          1  target correct  propensity_score  \
# 0     0.10285127 0.89714873       0      no        0.00000000
# 1     0.33247900 0.66752100       0      no        0.00000000
# 2     0.33793682 0.66206318       0      no        0.00000000
# 3     0.33933717 0.66066283       0      no        0.00000000
# 4     0.35224062 0.64775938       1     yes        0.00026759
# ...          ...        ...     ...     ...               ...
# 30484 0.99996108 0.00003893       0     yes        0.00000000
# 30485 0.99996722 0.00003276       0     yes        0.00000000
# 30486 0.99997008 0.00002992       0     yes        0.00000000
# 30487 0.99997121 0.00002878       0     yes        0.00000000
# 30488 0.99997807 0.00002192       0     yes        0.00000000
#
#        cumulative_propensity_score  cumulative_porc_base       lift  ranking  \
# 0                       0.00000000            0.00003280 0.00000000        1
# 1                       0.00000000            0.00006560 0.00000000        2
# 2                       0.00000000            0.00009840 0.00000000        3
# 3                       0.00000000            0.00013119 0.00000000        4
# 4                       0.00026759            0.00016399 1.63173669        5
# ...                            ...                   ...        ...      ...
# 30484                   1.00000000            0.99986881 1.00013121    30485
# 30485                   1.00000000            0.99990160 1.00009841    30486
# 30486                   1.00000000            0.99993440 1.00006560    30487
# 30487                   1.00000000            0.99996720 1.00003280    30488
# 30488                   1.00000000            1.00000000 1.00000000    30489
#
#        precision_at_k  recall_at_k
# 0          0.00000000   0.00000000
# 1          0.00000000   0.00000000
# 2          0.00000000   0.00000000
# 3          0.00000000   0.00000000
# 4          0.20000000   0.00026759
# ...               ...          ...
# 30484      0.12258488   1.00000000
# 30485      0.12258086   1.00000000
# 30486      0.12257684   1.00000000
# 30487      0.12257282   1.00000000
# 30488      0.12256880   1.00000000
#
# [30489 rows x 11 columns]

# %%
print(f"XGBoost - \nPrecision at 40% of base(k): {round( metrics_xgb[0] ,2)}\nRecall at 40% of base(k): {round( metrics_xgb[1] ,2) }")
# Out:
# XGBoost -
# Precision at 40% of base(k): 0.28
# Recall at 40% of base(k): 0.92

# %% [markdown]
# ## Models Single Performance

# %%
 #Single Performance Table (#k=40% of base)
prec_at_k_knn, recall_at_k_knn = metrics_knn
prec_at_k_cb, recall_at_k_cb = metrics_cb
prec_at_k_et, recall_at_k_et = metrics_et
prec_at_k_xgb, recall_at_k_xgb = metrics_xgb

dict_sing_perf = {
    'model': ['KNN', 'Catboost', 'Extra Trees', 'XGBoost'],
    'precision_at_k': [prec_at_k_knn, prec_at_k_cb, prec_at_k_et, prec_at_k_xgb],
    'recall_at_k': [recall_at_k_knn, recall_at_k_cb, recall_at_k_et, recall_at_k_xgb]
}

df_single_perf = pd.DataFrame(dict_sing_perf)
df_single_perf
# Out:
#          model  precision_at_k  recall_at_k
# 0          KNN      0.25270492   0.82499331
# 1     Catboost      0.28245902   0.92213005
# 2  Extra Trees      0.27057377   0.88332887
# 3      XGBoost      0.28295082   0.92373562

# %% [markdown]
# ## Models Evaluation

# %%
 # restore to default matplotlib and seaborn configuration
matplotlib.rc_file_defaults()
sns.reset_orig
sns.set_theme(font_scale = 1.2, style = 'whitegrid')

# plot the graphics
fig, axes = plt.subplots(1, 1, figsize=(8, 8))

# plot the graphics
sns.lineplot(ax = axes, x = df_perfect_model['cumulative_porc_base'], y = df_perfect_model['cumulative_propensity_score'], label="perfect model", linewidth = 2, color = 'black')
sns.lineplot(ax = axes, x = df_cb['cumulative_porc_base'], y = df_cb['cumulative_propensity_score'], label="Catboost", linewidth = 2)
sns.lineplot(ax = axes, x = df_knn['cumulative_porc_base'], y = df_knn['cumulative_propensity_score'], label="k-nearest neighbors ", linewidth = 2)
sns.lineplot(ax = axes, x = df_et['cumulative_porc_base'], y = df_et['cumulative_propensity_score'], label="extra trees classifier", linewidth = 2)
sns.lineplot(ax = axes, x = df_xgb['cumulative_porc_base'], y = df_xgb['cumulative_propensity_score'], label="xgboos classifier", linewidth = 2)
sns.lineplot(ax = axes, x = df_perfect_model['cumulative_porc_base'], y = df_perfect_model['cumulative_porc_base'], label="baseline (random pick up)", linewidth = 2, color = 'black')

axes.lines[0].set_linestyle(":")
axes.lines[4].set_linestyle("--")

axes.legend()
axes.set_title("Cumulative Gains curve")
axes.set_xlabel("Percentage of sample")
axes.set_ylabel("Gain")

axes.plot;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 11>()
#       7 fig, axes = plt.subplots(1, 1, figsize=(8, 8))
#       9 # plot the graphics
#      10 #sns.lineplot(ax = axes, x = df_perfect_model['cumulative_porc_base'], y = df_perfect_model['cumulative_propensity_score'], label="perfect model", linewidth = 2, color = 'black')
# ---> 11 sns.lineplot(ax = axes, x = df_cb['cumulative_porc_base'], y = df_cb['cumulative_propensity_score'], label="logistic regression", linewidth = 2)
#      12 sns.lineplot(ax = axes, x = df_knn['cumulative_porc_base'], y = df_knn['cumulative_propensity_score'], label="k-nearest neighbors ", linewidth = 2)
#      13 sns.lineplot(ax = axes, x = df_et['cumulative_porc_base'], y = df_et['cumulative_propensity_score'], label="extra trees classifier", linewidth = 2)
#
# NameError: name 'df_cb' is not defined

# %% [markdown]
# ## Cross-Validation

# %%
param = {
    'n_estimators':  [100, 300, 500],
    'max_depth': [3,5,9], 
    'scale_pos_weight': [1, 9]
}

max_eval = 5

for i in range(max_eval):
    # random choice of dictionary values
    hp = {k: random.sample(v,1)[0] for k, v in param.items()}
    print(hp)

    # model definition
    xgb_model = XGBClassifier(n_estimators = hp['n_estimators'],
                                        max_depth = hp['max_depth'],
                                        scale_pos_weight = hp['scale_pos_weight'],
                                        n_jobs= -1)
    
    
    display(cv.runCrossValidation(xgb_model, x_train, x_val, y_train, y_val, n_splits = 10, n_repeats = 2, top_k = 12200))
# Out:
# {'n_estimators': 500, 'max_depth': 9, 'scale_pos_weight': 1}
# [15:57:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:57:55] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:59:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:00:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:01:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:02:44] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:03:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:04:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:05:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:06:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:08:35] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:10:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:11:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:14:19] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:16:09] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:17:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:45] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:22:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:23:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                      mean        std
# precision_at_k 0.27610246 0.00138194
# recall_at_k    0.90142633 0.00450566
# {'n_estimators': 100, 'max_depth': 9, 'scale_pos_weight': 1}
# [16:24:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:24:55] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:25:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:25:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:25:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:25:55] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:26:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:26:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:26:28] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:26:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:26:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:27:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:27:12] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:27:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:27:36] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:27:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:30] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                      mean        std
# precision_at_k 0.28062295 0.00150190
# recall_at_k    0.91618492 0.00489191
# {'n_estimators': 100, 'max_depth': 3, 'scale_pos_weight': 1}
# [16:29:14] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:19] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:28] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:32] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:58] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:28] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                      mean        std
# precision_at_k 0.28294262 0.00118524
# recall_at_k    0.92375826 0.00385912
# {'n_estimators': 100, 'max_depth': 9, 'scale_pos_weight': 1}
# [16:30:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:18] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:31] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:09] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:21] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:45] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:58] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:34:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:34:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:34:31] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:34:44] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                      mean        std
# precision_at_k 0.28062295 0.00150190
# recall_at_k    0.91618492 0.00489191
# {'n_estimators': 100, 'max_depth': 3, 'scale_pos_weight': 9}
# [16:34:57] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:12] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:29] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:47] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:35:55] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:13] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                      mean        std
# precision_at_k 0.28325410 0.00125870
# recall_at_k    0.92477512 0.00408801

# %%
final_results = {'model':['#1', '#2', '#3', '#4', '#5'],
                 'precision_at_k': ['0.282832 +/- 0.001558',
                                    '0.281918 +/- 0.001467',
                                    '0.283037 +/- 0.001404',
                                    '0.282967 +/- 0.001357',
                                    '0.281963 +/- 0.001470'],
                 'recall_at_k': ['0.923397 +/- 0.005101',
                                 '0.920413 +/- 0.004814',
                                 '0.924066 +/- 0.004599',
                                 '0.923839 +/- 0.004447',
                                 '0.920560 +/- 0.004813'],
                 'parameters': ["'n_estimators': 100, 'max_depth': 5, 'scale_pos_weight': 9",
                                "'n_estimators': 100, 'max_depth': 3, 'scale_pos_weight': 1",
                                "'n_estimators': 300, 'max_depth': 5, 'scale_pos_weight': 1",
                                "'n_estimators': 300, 'max_depth': 3, 'scale_pos_weight': 1",
                                "'n_estimators': 500, 'max_depth': 5, 'scale_pos_weight': 9"]
                }

print(tabulate(final_results, headers=['model','precision@k','recall@k', 'hyperparameters'], tablefmt="fancy_grid"))
# Out:
# ╒═════════╤═══════════════════════╤═══════════════════════╤════════════════════════════════════════════════════════════╕
# │ model   │ precision@k           │ recall@k              │ hyperparameters                                            │
# ╞═════════╪═══════════════════════╪═══════════════════════╪════════════════════════════════════════════════════════════╡
# │ #1      │ 0.282832 +/- 0.001558 │ 0.923397 +/- 0.005101 │ 'n_estimators': 100, 'max_depth': 5, 'scale_pos_weight': 9 │
# ├─────────┼───────────────────────┼───────────────────────┼────────────────────────────────────────────────────────────┤
# │ #2      │ 0.281918 +/- 0.001467 │ 0.920413 +/- 0.004814 │ 'n_estimators': 100, 'max_depth': 3, 'scale_pos_weight': 1 │
# ├─────────┼───────────────────────┼───────────────────────┼────────────────────────────────────────────────────────────┤
# │ #3      │ 0.283037 +/- 0.001404 │ 0.924066 +/- 0.004599 │ 'n_estimators': 300, 'max_depth': 5, 'scale_pos_weight': 1 │
# ├─────────┼───────────────────────┼───────────────────────┼────────────────────────────────────────────────────────────┤
# │ #4      │ 0.282967 +/- 0.001357 │ 0.923839 +/- 0.004447 │ 'n_estimators': 300, 'max_depth': 3, 'scale_pos_weight': 1 │
# ├─────────┼───────────────────────┼───────────────────────┼────────────────────────────────────────────────────────────┤
# │ #5      │ 0.281963 +/- 0.001470 │ 0.920560 +/- 0.004813 │ 'n_estimators': 500, 'max_depth': 5, 'scale_pos_weight': 9 │
# ╘═════════╧═══════════════════════╧═══════════════════════╧════════════════════════════════════════════════════════════╛

# %% [markdown]
# ## Ploting Curves

# %%
 # model definition
xgbclassifier_model = XGBClassifier(n_estimators = 300,
                                    max_depth = 5,
                                    scale_pos_weight = 1,
                                    n_jobs= -1)

# model training
xgbclassifier_model.fit(x_train, y_train.values.ravel())

# model prediction (proba)
yhat_proba = xgbclassifier_model.predict_proba(x_val)
# Out:
# [16:42:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
able_xgb = cv.gain_lift_curve(yhat_proba, y_val)
metrics_xgb, new_table_xgb = cv.precision_recall_at_k(table_xgb, 12200) #12200 = 40% of customers
new_table_xgb.to_pickle(datapath+'processed/xgb_table.pkl')

# %%
#Table of XGBoost data
new_table_xgb
# Out:
#                0          1  target correct  propensity_score  \
# 0     0.06159067 0.93840933       0      no        0.00000000
# 1     0.27110255 0.72889745       0      no        0.00000000
# 2     0.28419161 0.71580839       1     yes        0.00026759
# 3     0.28472459 0.71527541       0      no        0.00000000
# 4     0.28848743 0.71151257       0      no        0.00000000
# ...          ...        ...     ...     ...               ...
# 30484 0.99999255 0.00000744       0     yes        0.00000000
# 30485 0.99999273 0.00000728       0     yes        0.00000000
# 30486 0.99999273 0.00000725       0     yes        0.00000000
# 30487 0.99999315 0.00000687       0     yes        0.00000000
# 30488 0.99999624 0.00000375       0     yes        0.00000000
#
#        cumulative_propensity_score  cumulative_porc_base       lift  ranking  \
# 0                       0.00000000            0.00003280 0.00000000        1
# 1                       0.00000000            0.00006560 0.00000000        2
# 2                       0.00026759            0.00009840 2.71956115        3
# 3                       0.00026759            0.00013119 2.03967086        4
# 4                       0.00026759            0.00016399 1.63173669        5
# ...                            ...                   ...        ...      ...
# 30484                   1.00000000            0.99986881 1.00013121    30485
# 30485                   1.00000000            0.99990160 1.00009841    30486
# 30486                   1.00000000            0.99993440 1.00006560    30487
# 30487                   1.00000000            0.99996720 1.00003280    30488
# 30488                   1.00000000            1.00000000 1.00000000    30489
#
#        precision_at_k  recall_at_k
# 0          0.00000000   0.00000000
# 1          0.00000000   0.00000000
# 2          0.33333333   0.00026759
# 3          0.25000000   0.00026759
# 4          0.20000000   0.00026759
# ...               ...          ...
# 30484      0.12258488   1.00000000
# 30485      0.12258086   1.00000000
# 30486      0.12257684   1.00000000
# 30487      0.12257282   1.00000000
# 30488      0.12256880   1.00000000
#
# [30489 rows x 11 columns]

# %%
#XGBoost: Metrics of precision@k and recall@k -> k=12200 (40% of base).
metrics_xgb
# Out:
# (0.28295081967213115, 0.9237356168049238)

# %% [markdown]
# ## Model Test

# %% [markdown]
#  In this section, let's train the XGBoost classifier with x_train and x_val datasets, and test using x_test dataset.
#
#
#  In this way, it will be possible to compare the performance of the model with training and validation data, and with test data.
#
#
#
#  It will then be possible to assess the model's generalizability, that is, the model's ability to rank never seen data.

# %%
 cols_selected = ['days_associated','health_annual_paid','age','region_code',
                 'vehicle_damage','policy_sales_channel', 'vehicle_prev_insured']

# %%
# unify train and validation datasets
x_train = pd.concat([x_train, x_val])
y_train = pd.concat([y_train, y_val])

# %%
x_train.head()
# Out:
#         days_associated  health_annual_paid        age  region_code  \
# 338532              129         -0.16219441 0.04615385   0.07436988
# 255428              288          0.32810064 0.43076923   0.12987505
# 186404              293          0.31159532 0.03076923   0.08855219
# 192264              156          3.72703949 0.69230769   0.18673594
# 59130               291          0.44259548 0.07692308   0.07995418
#
#         vehicle_damage  policy_sales_channel  vehicle_prev_insured
# 338532               0            0.35352770                     1
# 255428               1            0.19391775                     0
# 186404               0            0.35352770                     1
# 192264               1            0.20926442                     0
# 59130                0            0.35352770                     0

# %%
y_val
# Out:
#         response
# 357009         0
# 124985         0
# 352809         0
# 16666          0
# 303438         1
# ...          ...
# 106706         1
# 216249         0
# 255478         0
# 305621         0
# 51563          0
#
# [30489 rows x 1 columns]

# %%
y_train.head()
# Out:
#         response
# 338532         0
# 255428         0
# 186404         0
# 192264         0
# 59130          0

# %%
x_test.head()
# Out:
#             id  gender  age  region_code  policy_sales_channel  \
# 274973  291687    Male   37           15                   152
# 228952  304213    Male   27           15                   152
# 183928  327081  Female   64           28                    13
# 272592  272375    Male   21           25                   152
# 24869   198591  Female   26           47                   152
#
#         driving_license vehicle_age vehicle_damage  vehicle_prev_insured  \
# 274973                1    1-2 Year             No                     1
# 228952                1    < 1 Year             No                     1
# 183928                1    1-2 Year            Yes                     0
# 272592                1    < 1 Year             No                     1
# 24869                 1    < 1 Year            Yes                     0
#
#         health_annual_paid  days_associated
# 274973       2630.00000000              176
# 228952       2630.00000000               22
# 183928      61283.00000000              281
# 272592       2630.00000000              133
# 24869       31600.00000000              279

# %%
# unify train and validation datasets
x_train = pd.concat([x_train, x_val])
y_train = pd.concat([y_train, y_val])


# model definition
xboost_model  = XGBClassifier(n_estimators = 300,
                                    max_depth = 5,
                                    scale_pos_weight = 1,
                                    n_jobs= -1)

# model training
xboost_model .fit(x_train, y_train.values.ravel())

# model prediction (proba)
yhat_proba_xgb_final = xboost_model.predict_proba(x_test[cols_selected])
# Out:
# [16:41:44] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 16>()
#      13 xboost_model .fit(x_train, y_train.values.ravel())
#      15 # model prediction (proba)
# ---> 16 yhat_proba_xgb_final = xboost_model.predict_proba(x_test[cols_selected])
#
# File ~/anaconda3/envs/health_insurance/lib/python3.9/site-packages/xgboost/sklearn.py:1348, in XGBClassifier.predict_proba(self, X, ntree_limit, validate_features, base_margin, iteration_range)
#    1316 """ Predict the probability of each `X` example being of a given class.
#    1317
#    1318 .. note:: This function is only thread safe for `gbtree` and `dart`.
#    (...)
#    1341     probability of each data example being of a given class.
#    1342 """
#    1343 # custom obj:      Do nothing as we don't know what to do.
#    1344 # softprob:        Do nothing, output is proba.
#    1345 # softmax:         Use output margin to remove the argmax in PredTransform.
#    1346 # binary:logistic: Expand the prob vector into 2-class matrix after predict.
#    1347 # binary:logitraw: Unsupported by predict_proba()
# -> 1348 class_probs = super().predict(
#    1349     X=X,
#    1350     output_margin=self.objective == "multi:softmax",
#    1351     ntree_limit=ntree_limit,
#    1352     validate_features=validate_features,
#    1353     base_margin=base_margin,
#    1354     iteration_range=iteration_range
#    1355 )
#    1356 # If model is loaded from a raw booster there's no `n_classes_`
#    1357 return _cls_predict_proba(
#    1358     getattr(self, "n_classes_", None), class_probs, np.vstack
#    1359 )
#
# File ~/anaconda3/envs/health_insurance/lib/python3.9/site-packages/xgboost/sklearn.py:881, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     879 if self._can_use_inplace_predict():
#     880     try:
# --> 881         predts = self.get_booster().inplace_predict(
#     882             data=X,
#     883             iteration_range=iteration_range,
#     884             predict_type="margin" if output_margin else "value",
#     885             missing=self.missing,
#     886             base_margin=base_margin,
#     887             validate_features=validate_features,
#     888         )
#     889         if _is_cupy_array(predts):
#     890             import cupy     # pylint: disable=import-error
#
# File ~/anaconda3/envs/health_insurance/lib/python3.9/site-packages/xgboost/core.py:2033, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2031 if isinstance(data, np.ndarray):
#    2032     from .data import _ensure_np_dtype
# -> 2033     data, _ = _ensure_np_dtype(data, data.dtype)
#    2034     _check_call(
#    2035         _LIB.XGBoosterPredictFromDense(
#    2036             self.handle,
#    (...)
#    2043         )
#    2044     )
#    2045     return _prediction_output(shape, dims, preds, False)
#
# File ~/anaconda3/envs/health_insurance/lib/python3.9/site-packages/xgboost/data.py:138, in _ensure_np_dtype(data, dtype)
#     136 def _ensure_np_dtype(data, dtype):
#     137     if data.dtype.hasobject or data.dtype in [np.float16, np.bool_]:
# --> 138         data = data.astype(np.float32, copy=False)
#     139         dtype = np.float32
#     140     return data, dtype
#
# ValueError: could not convert string to float: 'No'

# %% [markdown]
# ### Cumulative Gains and Lift Curves

# %%
xgb_test = gain_lift_curve(yhat_proba_xgb_final, y_test, size = (10, 12))

# %% [markdown]
# ### Precision@k and recall@k

# %%
# two dictionaies, one for each metric
dict_precision = {'Precision@': ['10%' , '20%', '30%', '40%']}
dict_recall = {'Recall@': ['10%', '20%', '30%', '40%']}

# metrics (precision@k and recall@k) for 10%, 20%, 30%, 40% of the ranked list resulting from train and validation datasets
metrics10_train, _ = precision_recall_at_k(df_xgb,3049)
metrics20_train, _ = precision_recall_at_k(df_xgb,6098)
metrics30_train, _ = precision_recall_at_k(df_xgb,9147)
metrics40_train, _ = precision_recall_at_k(df_xgb,12196)

# metrics (precision@k and recall@k) for 10%, 20%, 30%, 40% of the ranked list resulting from test dataset
metrics10_test, _ = precision_recall_at_k(xgb_test,7622)
metrics20_test, _ = precision_recall_at_k(xgb_test,15244)
metrics30_test, _ = precision_recall_at_k(xgb_test,22866)
metrics40_test, _ = precision_recall_at_k(xgb_test,30488)


# construction of the two dictionaries to include 2 columns, one for each dataset, and 4 rows, one for each percentage
# train and valdation
dict_precision['xgboost classifier (train)'] = [round(metrics10_train[0], 2),
                                                round(metrics20_train[0], 2),
                                                round(metrics30_train[0], 2), 
                                                round(metrics40_train[0], 2)]
# test
dict_precision['xgboost classifier (test)'] = [round(metrics10_test[0], 2),
                                               round(metrics20_test[0], 2),
                                               round(metrics30_test[0], 2), 
                                               round(metrics40_test[0], 2)]


# train and valdation
dict_recall['xgboost classifier (train)'] = [round(metrics10_train[1], 2),
                                                round(metrics20_train[1], 2),
                                                round(metrics30_train[1], 2), 
                                                round(metrics40_train[1], 2)]
# test
dict_recall['xgboost classifier (test)'] = [round(metrics10_test[1], 2),
                                               round(metrics20_test[1], 2),
                                               round(metrics30_test[1], 2), 
                                               round(metrics40_test[1], 2)]

# convert the dictionary to dataframe
df_precision = pd.DataFrame(dict_precision).set_index('Precision@')
df_recall = pd.DataFrame(dict_recall).set_index('Recall@')

# %%
print(tabulate(df_precision, headers='keys', tablefmt='fancy_grid'))

# %%
print(tabulate(df_recall, headers='keys', tablefmt='fancy_grid'))

# %% [markdown]
# # 9.0. Business and Financial Results

# %% [markdown]
#      1. Principais Insights sobre os atributos mais relevantes de clientes interessados em adquirir um seguro de automóvel.
#      2. Qual a porcentagem de clientes interessados em adquirir um seguro de automóvel, o time de vendas conseguirá contatar fazendo 20.000 ligações?
#      3. E se a capacidade do time de vendas aumentar para 40.000 ligações, qual a porcentagem de clientes interessados em adquirir um seguro de automóvel o time de vendas conseguirá contatar?
#      4. Quantas ligações o time de vendas precisa fazer para contatar 80% dos clientes interessados em adquirir um seguro de automóvel?

# %% [markdown]
# ### What percentage of customers interested in purchasing vehicle insurance will the sales team be able to contact by making 20,000 calls?

# %%
data = x_test.copy()
data['target'] = y_test.copy()
data['response'] = yhat_proba_xgb_final[:, 1].tolist()
data = data.sort_values('response', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 3>()
#       1 data = x_test.copy()
#       2 data['target'] = y_test.copy()
# ----> 3 data['response'] = yhat_proba_xgb_final[:, 1].tolist()
#       4 data = data.sort_values('response', ascending=False)
#
# NameError: name 'yhat_proba_xgb_final' is not defined

# %%
percent_at_20k = 20000 / len(data)
recall_at_20k, table_20k = precision_recall_at_k(data, k=20000)

print(percent_at_20k)
print(recall_at_20k[1])

# %%
curves_at_20k = gain_lift_curve(yhat_proba_xgb_final, y_test, size = (10, 12), axvline=percent_at_20k)

# %%
#Scenario with 20000 phone calls
df_fin = pd.read_csv(datapath+'df3_feature_engeneering_done.csv', index_col=0)

print (f"We have {data.shape[0]} new customers, of which {round(data.loc[data['target'] == 1].shape[0])} are interested in vehicle insurance. ({round(data.loc[data['target'] == 1].shape[0] / data.shape[0] *100 ,2) }% of total new customers)")

print (f"The average ticket for an annual health insurance from Insurance All is: ${round(df_fin['health_annual_paid'].median())}.")
print (f"\nAssuming that all customers interested in vehicle insurance will sign the contract, and that the average value of vehicle insurance will be the same as the health insurance is, we can estimate as invoicing scenarios:")

print (f"\n_______________________________ SCENARIO WITH 20000 PHONE CALLS _____________________________________________________________________________")
print (f"By random list:")
print (f" - The sales team contacts {round(20000 / data.shape[0]*100 )}% of those interested in car insurance: {round( (20000 / data.shape[0]*100 ) / 100 * (round(data.loc[data['target'] == 1].shape[0])) )} customers (see Gain: intersection black x green line).\n  ==>  Estimated revenue: 2451 * 31669 = ${nm.numerize(77620719)} per year.")       

print (f"\nBy sorted list (model):")
print (f" - The sales team contacts {round(recall_at_20k[1]*100)}% of those interested in car insurance: {round( recall_at_20k[1]*100  / 100 * (data.loc[data['target'] == 1].shape[0]) )} customers (see Gain: intersection blue x green line).\n  ==> Estimated revenue: {round( recall_at_20k[1]*100  / 100 * (data.loc[data['target'] == 1].shape[0]) )} * 31669 = ${nm.numerize(208255344)} per year.")

print (f"\nRESULT: The model is {round(208255344 / 77620719 ,2)} times better than the random list (see Lift: intersection blue x green line). \nSo, the estimated revenue is {round(208255344 / 77620719 ,2)} times higher than the random list: ${nm.numerize(208255344 - 77620719)}.")

# %% [markdown]
# ###  And if the sales team's capacity increases to 40,000 calls, what percentage of customers interested in purchasing vehicle insurance will the sales team be able to contact?

# %%
percent_at_40k = 40000 / len(data)
recall_at_40k, table_40k = precision_recall_at_k(data, k=40000)

print(percent_at_40k)
print(recall_at_40k[1])

# %%
curves_at_40k = gain_lift_curve(yhat_proba_xgb_final, y_test, size = (10, 12), axvline=percent_at_40k)

# %%
#Scenario with 40000 phone calls
print (f"We have {data.shape[0]} new customers, of which {round(data.loc[data['target'] == 1].shape[0])} are interested in vehicle insurance. ({round(data.loc[data['target'] == 1].shape[0] / data.shape[0] *100 ,2) }% of total new customers)")
print (f"The average ticket for an annual health insurance from Insurance All is: ${round(df_fin['health_annual_paid'].median())}.")
print (f"\nAssuming that all customers interested in vehicle insurance will sign the contract, and that the average value of vehicle insurance will be the same as the health insurance is, we can estimate as invoicing scenarios:")

print (f"\n_______________________________ SCENARIO WITH 40000 PHONE CALLS_________________________________________________________________________")


print(f"By random list:")
print (f" - The sales team contacts {round(40000 / data.shape[0]*100 )}% of those interested in car insurance: {round( (40000 / data.shape[0]*100 ) / 100 * (round(data.loc[data['target'] == 1].shape[0])) )} customers (see Gain: intersection black x green line).\n ==> Estimated revenue = 4902 * 31669 = ${nm.numerize(155241438)} per year.")

print(f"\nBy sorted list (model): ")
print (f" - The sales team contacts {round(recall_at_40k[1]*100, 1)}% of those interested in car insurance: {round( recall_at_40k[1]*100 / 100 * (data.loc[data['target' ] == 1].shape[0]) )} customers (see Gain: intersection blue x green line).\n ==> Estimated revenue: 9291 * 31669 = ${nm.numerize(294236679)} per year.")

print(f"\nRESULT: The model is {round(294236679 / 155241438 ,2)} times better than the random list (see Lift: intersection blue x green line). \nSo the estimated revenue is {round(294236679 / 155241438 ,2)} times higher than the random list: ${nm.numerize(294236679 - 155241438)}." )

# %% [markdown]
# ### How many calls does the sales team need to make to contact 80% of customers interested in purchasing vehicle insurance?

# %%
percent_at_23k = 23800 / len(data)
recall_at_23k, table_23k = precision_recall_at_k(data, k=23800)

print(percent_at_23k)
print(recall_at_23k[1])

# %%
curves_at_23k = gain_lift_curve(yhat_proba_xgb_final, y_test, size = (10, 12), axvline=percent_at_23k)

# %%
#Scenario with 80% of interested
print(f"_______________________________ SCENARIO WITH 80% OF INTERESTED CUSTOMERS _____________________________________________________________________________")

print(f"By random list:")
print(f" - The sales team needs to make {round(0.8 * 76220)} calls, to contact 80% of the customers on the list, then will reach 80% of those interested in car insurance.")

print(f"\nBy sorted list (model): ")
print(f" - The sales team needs to make 23800 calls, to contact {round(percent_at_23k*100)}% of customers on the list, then will reach {round(recall_at_23k[1]*100)}% of those interested in car insurance ( see Gain: intersection blue x green line).")

print(f"\nRESULT: Making 23800 calls, the model is {round(60976 / 23800,2)} times better than the random list. (see Lift: intersection blue x green line).")

# %% [markdown]
# # 10.0. Deploy to Production

# %%
# save trained model
pickle.dump(xboost_model , open('/home/felipepedrosa/projetos/health_insurance/src/models/xgbclassifier_model.pkl' , 'wb'))

# %% [markdown]
# ## 9.1. API Tester

# %%
# loading test dataset

df_test = x_val
df_test['response'] = y_val

# %%
df_test = df_test.sample(10)

# %%
df_test

# %%
df_test.to_csv('propensy_score_test.csv')

# %%
# convert dataframe to json
data = json.dumps(df_test.to_dict(orient='records'))

# %%
data

# %%
# API Call

url = 'https://health-insurance-model-score.herokuapp.com/predict'
header = {'Content-type': 'application/json'}     

r = requests.post(url , data = data , headers = header)
print('Status code {}'.format(r.status_code))

# %%
d1 = pd.DataFrame( r.json(), columns=r.json()[0].keys() )
d1.sort_values('score', ascending = False).head()
